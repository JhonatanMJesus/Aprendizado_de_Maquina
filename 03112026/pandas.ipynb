# %% [markdown]
# ### 1. Importando a biblioteca
# Instale a biblioteca

# %%
# %pip install pandas

# %% [markdown]
# A convenção universal da comunidade é importar o Pandas com o alias Pandas

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### 2. Estrutura de dados: Series e DataFrames
# * Series: É uma matriz dimensional com rótulos (índices) - pode ser vista como uma única coluna de uma tabela
# * DataFrames: É uma estrutura bidimensional (linhas e colunas), como uma planilha completa - é essencialmente um conjunto de Series

# %%
# Criando uma Series
notas = pd.Series([8.5, 9.0, 7.5, 10], index=['Aluno A', 'Aluno B', 'Aluno C', 'Aluno D'])
print('Exemplo de Series: \n', notas, '\n')

# %%
# Criando um DataFrame a partir de um dicionário (útil para testes locais)

dados_turma = {
    'Nome': ['Ana', 'Bruno', 'Carlos', 'Diana'],
    'Idade': [20, 22, 23, 21],
    'Nota_Final': [8.5, 9.0, 7.5, 6.5],
    'Aprovado': [True, True, True, False]
}

df = pd.DataFrame(dados_turma)
print('Exemplo de DataFrame:')
display(df) # O display renderiza uma tabela mais bonita no Jupyter do que o 'print'

# %% [markdown]
# ### 3. Lendo dados de arquivos Externos (CSV)
# Na prática real de análise, nós raramente geramos os dados manualmente no código. O fluxo normal é ler os dados diretamente de arquivos, sendo o formato CSV o mais comum.

# %%
# O comando abaixo é o padrão para ler arquivos CSV.
# df_csv = pd.read_csv('caminho/do/arquivo.csv')

# Exemplo prático carregando um dataset público diretamente de uma URL para demonstração:
url = 'https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv'
df_titanic = pd.read_csv(url)
print("Dados carregados com sucesso!")
